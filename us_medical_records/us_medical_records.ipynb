# %% [markdown]
# # U.S. Medical Insurance Costs
#
# In this project, a **CSV** file with medical insurance costs will be investigated using Python fundamentals. The goal with this project will be to analyze various attributes within **insurance.csv** to learn more about the patient information in the file and gain insight into potential use cases for the dataset.

# %%
import csv
import json

# %%
file_name = "E:\\Semo4ka\\Python\\CodeCademy\\insurance.csv"

# %% [markdown]
# To start, all necessary libraries must be imported. For this project the only library needed is the `csv` library in order to work with the **insurance.csv** data. There are other potential libraries that could help with this project; however, for this analysis, using just the `csv` library will suffice.

# %% [markdown]
# The next step is to look through **insurance.csv** in order to get aquanted with the data. The following aspects of the data file will be checked in order to plan out how to import the data into a Python file:
# * The names of columns and rows
# * Any noticeable missing data
# * Types of values (numerical vs. categorical)

# %%
def load_data(file_name):
    
    with open(file_name) as insurance_file:
        file_reader = csv.DictReader(insurance_file)
        user_info = []
        for row in file_reader:
            user_info.append(row)
    
    return user_info

first_elem = json.dumps(load_data(file_name)[0], indent=2)
print(first_elem)
# Out:
# {
#   "age": "19",
#   "sex": "female",
#   "bmi": "27.9",
#   "children": "0",
#   "smoker": "yes",
#   "region": "southwest",
#   "charges": "16884.924"
# }

# %% [markdown]
# **insurance.csv** contains the following columns:
# * Patient Age
# * Patient Sex
# * Patient BMI
# * Patient Number of Children
# * Patient Smoking Status
# * Patient U.S Geopraphical Region
# * Patient Yearly Medical Insurance Cost

# %% [markdown]
# There are many aspects of the data that could be looked into. The following operations will be implemented:
# * find average age of the patients
# * return the number of males vs. females counted in the dataset
# * find geographical location of the patients
# * return the average yearly medical charges of the patients
# * creating a dictionary that contains all patient information
#
# To perform these inspections, a class called `PatientsInfo` has been built out which contains fives methods:
# * `analyze_ages()`
# * `analyze_sexes()`
# * `unique_regions()`
# * `average_charges()`
# * `create_dictionary()`
#
# The class has been built out below.

# %%
class Patient:
    def __init__(self, age, sex, bmi, children, smoker, region, charges):
        self.age = int(age) 
        self.sex = sex
        self.bmi = float(bmi)
        self.children = int(children)
        self.smoker = smoker
        self.region = region
        self.charges = float(charges)
        
        
class PatientsInfo:
    def __init__(self):
        self.records = []
        
        
    def analyze_ages(self):
        age_total = 0
        for item in self.records:
            age_total += int(item.age)
        age_average = age_total / len(self.records) 
        
        return age_average
    
    def age_with_kids(self):
        age_total_with_kids = 0
        count_with_kids = 0
        for item in self.records:
            if item.children > 0:
                age_total_with_kids += item.age
                count_with_kids += 1
        average_age_with_kids = age_total_with_kids / count_with_kids
               
        return average_age_with_kids
            
           
    def analyze_sexes(self):
        male_count = 0
        female_count = 0
        for item in self.records:
            if item.sex == "male":
                male_count += 1
            else:
                female_count += 1
                
        return male_count, female_count
    
    
    def unique_regions(self):
        regions_list = []
        for item in self.records:
            if item.region not in regions_list:
                regions_list.append(item.region)
        
        return regions_list
    
    
    def regions_count(self):
        regions_total = {item: 0 for item in self.unique_regions()}
        for item in self.records:
            for key, val in regions_total.items():
                if item.region == key:
                    regions_total[key] += 1
        max_region = max(regions_total, key=regions_total.get)
        
        return regions_total, max_region
                  
            
    def average_charges(self):
        charges_total = 0
        for item in self.records:
            charges_total += float(item.charges)
        charges_avarage = charges_total / len(self.records) 
        
        return charges_avarage
    
    def create_dictionary(self):
        generations = {
            "gen_z": [10,25],
            "millenials": [26, 41],
            "gen_x": [42, 57],
            "boomers_2": [58, 67],
            "boomers_1": [68, 76],
            "post_war": [77, 94],
            "ww_2": [95, 100]
        }
        patients_dictionary = {key: [] for key in generations}
               
        for item in self.records:
            for k, v in generations.items():
                if item.age >= v[0] and item.age <= v[1]:
                    patients_dictionary[k].append({
                        "Patient Age": item.age,
                        "Patient Sex": item.sex,
                        "Patient BMI": item.bmi,
                        "Patient Number of Children": item.children,
                        "Patient Smoking Status": item.smoker,
                        "Patient U.S Geopraphical Region": item.region,
                        "Patient Yearly Medical Insurance Cost": item.charges
                    })
        
        return patients_dictionary
    
    def age_charges_correlation(self):
        patients_count = {}
        data = self.create_dictionary()
        age_charges_avarage = {}
        
        for k, v in data.items():
            patients_count[k] = len(v)
            if len(v) != 0:
                age_charges_avarage[k] = "{:.2f}".format(sum([record["Patient Yearly Medical Insurance Cost"] for record in v]) / len(v))
            
        return patients_count, age_charges_avarage
    
    
    def smokers_vs_nonsmokers(self):
        smoker_charge = 0
        smoker_count = 0
        nonsmoker_charge = 0
        nonsmoker_count = 0
        for item in self.records:
            if item.smoker == "yes":
                smoker_charge += item.charges
                smoker_count += 1
            else:
                nonsmoker_charge += item.charges
                nonsmoker_count += 1
        smoker_average_charge = smoker_charge / smoker_count
        nonsmoker_average_charge = nonsmoker_charge / nonsmoker_count
        difference_dol = smoker_average_charge - nonsmoker_average_charge
        difference_percent = difference_dol / nonsmoker_average_charge *100
        
        return smoker_average_charge, nonsmoker_average_charge, difference_dol, difference_percent

# %% [markdown]
# The next step is to create an instance of the class called `patient_info`. With this instance, each method can be used to see the results of the analysis.

# %%
def load_data(file_name):
    
    with open(file_name) as insurance_file:
        file_reader = csv.DictReader(insurance_file)
        user_info = PatientsInfo()
        for row in file_reader:
            user_info.records.append(Patient(row["age"], row["sex"], row["bmi"], row["children"], row["smoker"], row["region"], row["charges"]))
    
    return user_info

# %%
print("Average Patient Age: {:.2f} years".format(load_data(file_name).analyze_ages()))
# Out:
# Average Patient Age: 39.21 years

# %% [markdown]
# The average age of the patients in **insurance.csv** is about 39 years old. This is important to check in order to ensure the data in **insurance.csv** is representative for a broader population. If it is decided to use the dataset to make inferences about other populations, the data must abundant and broad enough for such use cases.
#
# A further analysis would have to be done to make sure the range and standard deviation of the patient age group in **insurance.csv** is indicative of a random sampling of individuals.

# %%
male_count, female_count = load_data(file_name).analyze_sexes()
print("Count for female: {}\nCount for male: {}".format(female_count, male_count))
# Out:
# Count for female: 662
# Count for male: 676

# %% [markdown]
# The next step of the analysis is to check the balance of males vs. females in **insurance.csv**. Similar to above, it is important to check that this dataset is representative of a broader population of individuals. If a person were to use this dataset to create a classification model, it would be imperitive to make sure that the attributes are balanced.
#
# Quite often in the real-world, data is not balanced; this is an issue because it can lead to statistical issues when performing analysis. This is something that will be explored further in future portfolio projects!

# %%
print("Analyzed U.S. regions : {}".format(load_data(file_name).unique_regions()))
# Out:
# Analyzed U.S. regions : ['southwest', 'southeast', 'northwest', 'northeast']

# %% [markdown]
# There are four unique geographical regions in this dataset, and it is important to note that all the patients come from the United States.

# %%
print("Average Yearly Medical Insurance Charges: {:.2f} dollars".format(load_data(file_name).average_charges()))
# Out:
# Average Yearly Medical Insurance Charges: 13270.42 dollars

# %% [markdown]
# The average yearly medical insurance charge per individual is 13270 US dollars. Some further analysis could be done to see what patient attributes contribute most strongly to low and/or high medical insurance charges. For example, one could check if patient age correlates with the amount of money they spend yearly.

# %%
print(json.dumps(load_data(file_name).create_dictionary(), indent=4))
# Out:
# {
#     "gen_z": [
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 27.9,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 16884.924
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 33.77,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1725.5523
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 26.22,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2721.3208
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "male",
#             "Patient BMI": 34.4,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1826.843
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 24.6,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1837.237
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "male",
#             "Patient BMI": 23.845,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2395.17155
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 34.1,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1137.011
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "male",
#             "Patient BMI": 17.385,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2775.19215
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 35.6,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 35585.576
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 26.315,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2198.18985
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 28.6,
#             "Patient Number of Children": 5,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 4687.797
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 20.425,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1625.43375
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "female",
#             "Patient BMI": 26.6,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3046.062
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 38.665,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3393.35635
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 35.625,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2211.13075
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 33.63,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 3579.8287
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 31.68,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 34303.1672
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 33.66,
#             "Patient Number of Children": 4,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 4504.6624
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 22.42,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 14711.7438
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 28.9,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1743.214
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "male",
#             "Patient BMI": 35.53,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1532.4697
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "female",
#             "Patient BMI": 39.805,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2755.02095
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 37.62,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 37165.1638
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 39.49,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2026.9741
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 30.115,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 21344.8467
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 28.025,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 17560.37975
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 28.4,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 2331.519
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 35.72,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2404.7338
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 23.75,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 1705.6245
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 28.975,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2257.47525
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 28.3,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 17081.08
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 25.555,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1632.56445
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 28.785,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2457.21115
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "female",
#             "Patient BMI": 28.05,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2155.6815
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 34.1,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1261.442
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 25.175,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2045.68525
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "female",
#             "Patient BMI": 36.0,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 2166.732
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 28.4,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1842.519
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 25.175,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 15518.18025
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 36.85,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 36149.4835
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 37.0,
#             "Patient Number of Children": 5,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 4830.63
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 31.825,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2719.27975
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 15.96,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 1694.7964
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "female",
#             "Patient BMI": 33.345,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2855.43755
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 38.28,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1631.8212
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 19.95,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 4005.4225
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 25.74,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2137.6536
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 34.43,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1137.4697
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 30.59,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1639.5631
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 32.11,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2130.6759
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 33.0,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1980.07
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "male",
#             "Patient BMI": 28.5,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 3537.703
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "female",
#             "Patient BMI": 23.21,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 25081.76784
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 34.8,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 34779.615
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 17.8,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1727.785
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 26.73,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1615.7667
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 29.07,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 17352.6803
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "female",
#             "Patient BMI": 36.67,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 38511.6283
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "male",
#             "Patient BMI": 35.86,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1986.9334
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 20.9,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1832.094
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 17.29,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 12829.4551
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 31.92,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 33750.2918
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 26.84,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 17085.2676
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 36.955,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 36219.40545
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 29.37,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1719.4363
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 27.55,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2523.1695
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 20.615,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2803.69785
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "female",
#             "Patient BMI": 24.3,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 2150.469
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 45.54,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 42112.2356
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "female",
#             "Patient BMI": 28.82,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2156.7518
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 26.8,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 3906.127
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 22.99,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 1704.5681
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 27.7,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 16297.846
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 24.7,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1737.376
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "female",
#             "Patient BMI": 27.6,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 18955.22017
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 27.835,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1635.73365
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 38.28,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 14133.03775
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "male",
#             "Patient BMI": 41.91,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1837.2819
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 20.79,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1607.5101
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 21.7,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 13844.506
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 26.4,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 2597.779
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 21.89,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 3180.5101
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 30.4,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3481.868
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 33.33,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1391.5287
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "female",
#             "Patient BMI": 28.31,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 18033.9679
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "male",
#             "Patient BMI": 40.15,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 38126.2465
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 34.4,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1261.859
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "female",
#             "Patient BMI": 30.21,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 4618.0799
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 37.43,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2138.0707
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "male",
#             "Patient BMI": 31.02,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 16586.49771
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 38.17,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1631.6683
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 17.48,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1621.3402
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 23.9,
#             "Patient Number of Children": 5,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 5080.096
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 35.15,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2134.9015
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 30.59,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2727.3951
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 29.165,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 7323.734819
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 16.815,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3167.45585
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 33.1,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 23082.95533
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 31.73,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2254.7967
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 43.01,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1149.3959
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "male",
#             "Patient BMI": 23.4,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1969.614
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 29.735,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1769.53165
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 25.175,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1632.03625
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 24.09,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2201.0971
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 30.115,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2203.47185
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 29.8,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1744.465
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "male",
#             "Patient BMI": 28.5,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 35147.52848
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "male",
#             "Patient BMI": 35.625,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2534.39375
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "male",
#             "Patient BMI": 36.85,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1534.3045
#         },
#         {
#             "Patient Age": 23,
#             "Patient Sex": "male",
#             "Patient BMI": 32.56,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1824.2854
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 31.35,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1622.1885
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 28.7,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1253.936
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 32.9,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1748.774
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 25.08,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2196.4732
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "male",
#             "Patient BMI": 25.7,
#             "Patient Number of Children": 4,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 17942.106
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 27.93,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 1967.0227
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 30.25,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 32548.3405
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 31.35,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2643.2685
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "male",
#             "Patient BMI": 23.75,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 3077.0955
#         },
#         {
#             "Patient Age": 24,
#             "Patient Sex": "female",
#             "Patient BMI": 25.27,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3044.2133
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 30.4,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1256.299
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 35.31,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 27724.28875
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 33.88,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 11482.63485
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 30.59,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 24059.68019
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "male",
#             "Patient BMI": 25.46,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 1708.0014
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 31.79,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 3056.3881
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "female",
#             "Patient BMI": 28.595,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3213.62205
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "female",
#             "Patient BMI": 41.325,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 17878.90068
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 35.53,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1646.4297
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 32.12,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2801.2588
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 30.495,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 2128.43105
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 37.29,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2219.4451
#         },
#         {
#             "Patient Age": 22,
#             "Patient Sex": "male",
#             "Patient BMI": 26.84,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1664.9996
#         },
#         {
#             "Patient Age": 25,
#             "Patient Sex": "female",
#             "Patient BMI": 23.465,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3206.49135
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 30.59,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 1639.5631
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "male",
#             "Patient BMI": 20.7,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 1242.816
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "male",
#             "Patient BMI": 20.235,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 3861.20965
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "male",
#             "Patient BMI": 31.13,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 2566.4707
#         },
#         {
#             "Patient Age": 21,
#             "Patient Sex": "female",
#             "Patient BMI": 21.85,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 15359.1045
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 39.16,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1633.0444
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 28.31,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 17468.9839
#         },
#         {
#             "Patient Age": 18,
#             "Patient Sex": "female",
#             "Patient BMI": 33.155,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 2207.69745
#         },
#         {
#             "Patient Age": 20,
#             "Patient Sex": "female",
#             "Patient BMI": 33.0,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 1880.07
#         },
#         {
#             "Patient Age": 19,
#             "Patient Sex": "female",
#             "Patient BMI": 33.11,
#             "Patient Number of Children": 0,
# ...
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 14119.62
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "male",
#             "Patient BMI": 23.655,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 13129.60345
#         },
#         {
#             "Patient Age": 64,
#             "Patient Sex": "female",
#             "Patient BMI": 26.885,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 29330.98315
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "male",
#             "Patient BMI": 32.11,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 13555.0049
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "female",
#             "Patient BMI": 44.0,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 13063.883
#         },
#         {
#             "Patient Age": 60,
#             "Patient Sex": "male",
#             "Patient BMI": 40.92,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 48673.5588
#         },
#         {
#             "Patient Age": 60,
#             "Patient Sex": "female",
#             "Patient BMI": 35.1,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 12644.589
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "male",
#             "Patient BMI": 39.8,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 15170.069
#         },
#         {
#             "Patient Age": 59,
#             "Patient Sex": "female",
#             "Patient BMI": 26.695,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 14382.70905
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "female",
#             "Patient BMI": 28.2,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 13041.921
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "female",
#             "Patient BMI": 25.0,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 13451.122
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "female",
#             "Patient BMI": 33.2,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 13462.52
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "female",
#             "Patient BMI": 39.16,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 13470.8044
#         },
#         {
#             "Patient Age": 59,
#             "Patient Sex": "female",
#             "Patient BMI": 27.5,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 12233.828
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "male",
#             "Patient BMI": 39.93,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 12982.8747
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "female",
#             "Patient BMI": 35.2,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 14474.675
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "female",
#             "Patient BMI": 36.85,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 13887.9685
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "female",
#             "Patient BMI": 33.33,
#             "Patient Number of Children": 4,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 36580.28216
#         },
#         {
#             "Patient Age": 59,
#             "Patient Sex": "male",
#             "Patient BMI": 25.46,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 12124.9924
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "male",
#             "Patient BMI": 38.38,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 12950.0712
#         },
#         {
#             "Patient Age": 64,
#             "Patient Sex": "male",
#             "Patient BMI": 26.41,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 14394.5579
#         },
#         {
#             "Patient Age": 59,
#             "Patient Sex": "male",
#             "Patient BMI": 41.14,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 48970.2476
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "male",
#             "Patient BMI": 21.66,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 14349.8544
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "male",
#             "Patient BMI": 31.445,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 13974.45555
#         },
#         {
#             "Patient Age": 60,
#             "Patient Sex": "female",
#             "Patient BMI": 18.335,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 13204.28565
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "male",
#             "Patient BMI": 33.66,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 15161.5344
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "female",
#             "Patient BMI": 30.495,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 15019.76005
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "male",
#             "Patient BMI": 36.08,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 11363.2832
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "female",
#             "Patient BMI": 25.08,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 14254.6082
#         },
#         {
#             "Patient Age": 60,
#             "Patient Sex": "male",
#             "Patient BMI": 32.8,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 52590.82939
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "female",
#             "Patient BMI": 36.48,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 12235.8392
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "female",
#             "Patient BMI": 32.68,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 13844.7972
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "female",
#             "Patient BMI": 32.395,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 13019.16105
#         },
#         {
#             "Patient Age": 59,
#             "Patient Sex": "female",
#             "Patient BMI": 34.8,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 36910.60803
#         },
#         {
#             "Patient Age": 59,
#             "Patient Sex": "male",
#             "Patient BMI": 37.1,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 12347.172
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "male",
#             "Patient BMI": 30.305,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 11938.25595
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "male",
#             "Patient BMI": 23.3,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 11345.519
#         },
#         {
#             "Patient Age": 63,
#             "Patient Sex": "female",
#             "Patient BMI": 21.66,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 14449.8544
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "female",
#             "Patient BMI": 28.215,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 12224.35085
#         },
#         {
#             "Patient Age": 64,
#             "Patient Sex": "male",
#             "Patient BMI": 36.96,
#             "Patient Number of Children": 2,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 49577.6624
#         },
#         {
#             "Patient Age": 64,
#             "Patient Sex": "male",
#             "Patient BMI": 23.76,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 26926.5144
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "male",
#             "Patient BMI": 36.3,
#             "Patient Number of Children": 1,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "southwest",
#             "Patient Yearly Medical Insurance Cost": 47403.88
#         },
#         {
#             "Patient Age": 58,
#             "Patient Sex": "male",
#             "Patient BMI": 25.175,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 11931.12525
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "male",
#             "Patient BMI": 30.875,
#             "Patient Number of Children": 3,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 46718.16325
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "male",
#             "Patient BMI": 26.695,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 28101.33305
#         },
#         {
#             "Patient Age": 62,
#             "Patient Sex": "male",
#             "Patient BMI": 38.83,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "southeast",
#             "Patient Yearly Medical Insurance Cost": 12981.3457
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "male",
#             "Patient BMI": 33.535,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "no",
#             "Patient U.S Geopraphical Region": "northeast",
#             "Patient Yearly Medical Insurance Cost": 13143.33665
#         },
#         {
#             "Patient Age": 61,
#             "Patient Sex": "female",
#             "Patient BMI": 29.07,
#             "Patient Number of Children": 0,
#             "Patient Smoking Status": "yes",
#             "Patient U.S Geopraphical Region": "northwest",
#             "Patient Yearly Medical Insurance Cost": 29141.3603
#         }
#     ],
#     "boomers_1": [],
#     "post_war": [],
#     "ww_2": []
# }

# %%
patients_count, age_charges_avarage = load_data(file_name).age_charges_correlation()
print("Patients count by generation:\n{}\nAverage Yearly Medical Insurance Cost by generation:\n{}".format(patients_count, age_charges_avarage))
# Out:
# Patients count by generation:
# {'gen_z': 306, 'millenials': 422, 'gen_x': 446, 'boomers_2': 164, 'boomers_1': 0, 'post_war': 0, 'ww_2': 0}
# Average Yearly Medical Insurance Cost by generation:
# {'gen_z': '9087.02', 'millenials': '11004.36', 'gen_x': '15896.22', 'boomers_2': '19766.12'}

# %%
regions_total, max_region = load_data(file_name).regions_count()
print("Patients represented by region: {}\nMajority of the individuals are from: {}".format(regions_total, max_region))
# Out:
# Patients represented by region: {'southwest': 325, 'southeast': 364, 'northwest': 325, 'northeast': 324}
# Majority of the individuals are from: southeast

# %%
smoker_average_charge, nonsmoker_average_charge, difference_dol, difference_percent = load_data(file_name).smokers_vs_nonsmokers()

print("Smoking individuals spend on average {:.2f} dollars for their yearly medical insurance.\nAt the same time non-smokers spend on avaerage {:.2f} dollars a year.\nThat means, that smokers pay {:.2f} dollars more and {:.2f}% more, than non-smokers.".format(smoker_average_charge, nonsmoker_average_charge, difference_dol, difference_percent))
# Out:
# Smoking individuals spend on average 32050.23 dollars for their yearly medical insurance.
# At the same time non-smokers spend on avaerage 8434.27 dollars a year.
# That means, that smokers pay 23615.96 dollars more and 280.00% more, than non-smokers.

# %%
print("Average Patient's Age for those, who has at least one child is: {:.2f} years".format(load_data(file_name).age_with_kids()))
# Out:
# Average Patient's Age for those, who has at least one child is: 39.78 years

# %% [markdown]
# All patient data is now neatly organized in a dictionary. This is convenient for further analysis if a decision is made to continue making investigations for the attributes in **insurance.csv**.
